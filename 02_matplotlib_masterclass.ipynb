# %% [markdown]
# # Matplotlib Visualization Masterclass
# ## Complete 6-Page Tutorial with Detailed Explanations
#
# This notebook covers:
# - Basic to advanced Matplotlib plotting techniques
# - Customization options and best practices
# - 3D visualization and interactive plots
# - Professional styling and output

# %% [markdown]
# ## Page 1/6: Introduction & Basic Plots
#
# Key concepts:
# - Figure and axes creation
# - Basic line plotting
# - Title and label customization
# - Legend and grid options

# %%
# Import core libraries
import numpy as np  # Numerical computing
import matplotlib.pyplot as plt  # Main plotting library
# %matplotlib inline  # Display plots inline in Jupyter

# Check available built-in styles
print("Available styles:", plt.style.available)  # Shows predefined style options

# Create basic line plot (using default style)
x = np.linspace(0, 10, 100)  # Generate 100 points from 0 to 10
plt.figure(figsize=(8, 4))  # Create figure with specific size (width, height)

# Plot sine curve with customization
plt.plot(x, np.sin(x), 
         label='sin(x)',  # Legend label
         color='blue',    # Line color
         linestyle='-',   # Solid line
         linewidth=2)     # Line thickness

# Plot cosine curve with different style
plt.plot(x, np.cos(x), 
         label='cos(x)', 
         color='red', 
         linestyle='--',  # Dashed line
         linewidth=2)

# Add title and labels
plt.title("Basic Trigonometric Functions", fontsize=14)  # Title with font size
plt.xlabel("X values", fontsize=12)  # X-axis label
plt.ylabel("Function values", fontsize=12)  # Y-axis label

plt.legend()  # Show legend
plt.grid(True, alpha=0.3)  # Add semi-transparent grid
plt.show()  # Display plot
# Out:
# Available styles: ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# ## Page 2/6: Customizing Plots & Subplots
#
# Key concepts:
# - Using predefined styles
# - Creating subplot grids
# - Different plot types (histogram, pie, bar, scatter)
# - Layout management

# %%
# Apply ggplot style (similar to R's ggplot2)
plt.style.use('ggplot')  # Professional style with gray background

# Create 2x2 grid of subplots
plt.figure(figsize=(10, 6))  # Larger figure for subplots

# Subplot 1: Histogram
plt.subplot(2, 2, 1)  # (rows, cols, position)
x = np.random.normal(0, 1, 1000)  # Generate normal distribution data
plt.hist(x, 
         bins=30,           # Number of bins
         color='skyblue',   # Fill color
         edgecolor='black') # Bin edge color
plt.title("Histogram")

# Subplot 2: Pie chart
plt.subplot(2, 2, 2)
sizes = [30, 25, 15, 10, 20]  # Wedge sizes
labels = ['A', 'B', 'C', 'D', 'E']  # Wedge labels
plt.pie(sizes, 
        labels=labels, 
        autopct='%1.1f%%',  # Show percentages
        colors=['gold', 'lightcoral', 'lightskyblue', 'lightgreen', 'violet'])
plt.title("Pie Chart")

# Subplot 3: Bar plot
plt.subplot(2, 2, 3)
x = ['A', 'B', 'C', 'D']  # Categories
y = [10, 25, 15, 30]      # Values
plt.bar(x, y, color='teal')  # Create bars
plt.title("Bar Plot")

# Subplot 4: Scatter plot
plt.subplot(2, 2, 4)
x = np.linspace(0, 10, 50)
y = x**2 + np.random.normal(0, 5, 50)  # Add noise
plt.scatter(x, y, 
            color='crimson',  # Point color
            alpha=0.7)        # Transparency
plt.title("Scatter Plot")

# Adjust layout to prevent overlap
plt.tight_layout()  # Automatically adjust spacing
plt.suptitle("Common Plot Types", y=1.02, fontsize=16)  # Super title
plt.show()

# %% [markdown]
# ## Page 3/6: Advanced Customization
#
# Key concepts:
# - Seaborn style integration
# - Advanced annotations
# - Fill between areas
# - Spine and grid customization

# %%
# Try using Seaborn style if available
try:
    import seaborn as sns
    sns.set_style("whitegrid")  # Clean style with grid
    print("Seaborn style applied successfully")
except ImportError:
    plt.style.use('default')  # Fallback to default
    print("Using default matplotlib style")

# Create data for plotting
x = np.linspace(0, 10, 200)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.exp(-x/3)*np.sin(3*x)  # Damped sine wave

# Create figure and axis objects
fig, ax = plt.subplots(figsize=(10, 5))  # Object-oriented interface

# Plot three curves with different styles
ax.plot(x, y1, label='sin(x)', linewidth=2)
ax.plot(x, y2, label='cos(x)', linewidth=2)
ax.plot(x, y3, label='damped sine', linewidth=2)

# Set title and labels with padding
ax.set_title("Advanced Plot Customization", fontsize=16, pad=20)
ax.set_xlabel("X Axis", fontsize=12)
ax.set_ylabel("Y Axis", fontsize=12)

# Customize legend
ax.legend(fontsize=10, framealpha=1)  # Opaque legend box

# Grid customization
ax.grid(True, linestyle='--', alpha=0.6)  # Dashed semi-transparent grid

# Remove top and right spines
for spine in ['top', 'right']:
    ax.spines[spine].set_visible(False)

# Add annotation with arrow
ax.annotate('Local max', 
            xy=(1.57, 1),       # Arrow tip (pi/2, 1)
            xytext=(3, 1.5),    # Text position
            arrowprops=dict(facecolor='black', shrink=0.05))

# Fill between curves
ax.fill_between(x, y1, y2, 
                where=(y1 > y2), 
                color='green', 
                alpha=0.2, 
                label='sin > cos')
ax.fill_between(x, y1, y2, 
                where=(y1 <= y2), 
                color='red', 
                alpha=0.2, 
                label='sin ≤ cos')

plt.show()
# Out:
# Seaborn style applied successfully

# %% [markdown]
# ## Page 4/6: Specialized Plots
#
# Key concepts:
# - Heatmaps
# - Contour plots
# - Box plots
# - Polar plots

# %%
# Reset to default style for specialized plots
plt.style.use('default')

# Create 2x2 grid for specialized plots
plt.figure(figsize=(12, 8))

# Subplot 1: Heatmap
plt.subplot(2, 2, 1)
data = np.random.rand(10, 10)  # 10x10 random data
plt.imshow(data, 
           cmap='viridis')     # Color map
plt.colorbar()                 # Add color scale
plt.title("Heatmap")

# Subplot 2: Contour plot
plt.subplot(2, 2, 2)
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)  # Create grid
Z = np.sin(np.sqrt(X**2 + Y**2))  # Calculate values
plt.contourf(X, Y, Z, 20, cmap='RdYlBu')  # Filled contours
plt.colorbar()
plt.title("Contour Plot")

# Subplot 3: Box plot
plt.subplot(2, 2, 3)
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
plt.boxplot(data, 
            patch_artist=True,  # Color boxes
            boxprops=dict(facecolor='lightblue'),
            whiskerprops=dict(color='black'),
            medianprops=dict(color='red'))  # Median line color
plt.title("Box Plot")

# Subplot 4: Polar plot
plt.subplot(2, 2, 4, polar=True)  # Polar projection
theta = np.linspace(0, 2*np.pi, 100)
r = 2 + np.sin(5*theta)  # Rose curve
plt.plot(theta, r, color='purple')
plt.title("Polar Plot", pad=20)  # Extra padding

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Page 5/6: 3D Visualization
#
# Key concepts:
# - 3D surface plots
# - 3D scatter plots
# - Viewpoint adjustment
# - Color mapping

# %%
from mpl_toolkits.mplot3d import Axes3D  # Required for 3D plots

# 3D Surface plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')  # Create 3D axis

# Generate grid and surface data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))  # Calculate z-values

# Plot surface with color mapping
surf = ax.plot_surface(X, Y, Z, 
                       cmap='coolwarm',  # Blue-red color map
                       linewidth=0,      # No wireframe lines
                       antialiased=False) # Faster rendering

# Add color bar
fig.colorbar(surf, shrink=0.5, aspect=5)

# Set labels
ax.set_title("3D Surface Plot", fontsize=14)
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

# 3D Scatter plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Generate random 3D data
n = 100
x = np.random.rand(n)
y = np.random.rand(n)
z = np.random.rand(n)
colors = np.random.rand(n)  # Color values
sizes = 1000 * np.random.rand(n)  # Size values

# Create scatter plot
scatter = ax.scatter(x, y, z, 
                     c=colors,      # Color mapping
                     s=sizes,       # Size mapping
                     alpha=0.6,     # Transparency
                     cmap='viridis') # Color map

# Add color bar
fig.colorbar(scatter, shrink=0.5, aspect=5)
ax.set_title("3D Scatter Plot", fontsize=14)
plt.show()

# %% [markdown]
# ## Page 6/6: Animation & Interactive Plots
#
# Key concepts:
# - Creating animations
# - Interactive widgets
# - Real-time plot updates
# - Jupyter notebook integration

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

# Animation example
fig, ax = plt.subplots(figsize=(8, 5))
x = np.linspace(0, 2*np.pi, 200)
line, = ax.plot(x, np.sin(x))  # Initial plot

# Animation function
def animate(i):
    line.set_ydata(np.sin(x + i/10))  # Update y-data
    return line,

# Create animation
ani = FuncAnimation(fig, 
                    animate, 
                    frames=100,  # Number of frames
                    interval=50,  # Delay between frames (ms)
                    blit=True)    # Optimize rendering

plt.close()  # Prevent duplicate display
HTML(ani.to_jshtml())  # Display in notebook

# Interactive widgets
from ipywidgets import interact

def plot_function(frequency=1.0, amplitude=1.0):
    plt.figure(figsize=(8, 4))
    x = np.linspace(0, 10, 200)
    y = amplitude * np.sin(frequency * x)
    plt.plot(x, y)
    plt.ylim(-3, 3)
    plt.title(f"Sine Wave: {frequency} Hz, {amplitude} Amp")
    plt.grid(True)
    plt.show()

# Create interactive controls
interact(plot_function, 
         frequency=(0.1, 5.0, 0.1),  # Range and step
         amplitude=(0.1, 2.0, 0.1));
# Out:
# interactive(children=(FloatSlider(value=1.0, description='frequency', max=5.0, min=0.1), FloatSlider(value=1.0…
